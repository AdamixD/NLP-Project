# %% [markdown]
# # Data Analyzing - English

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd

from sklearn.model_selection import train_test_split

from data_analyzing.data_analyzer import DataAnalyzer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adamdabkowski/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adamdabkowski/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/adamdabkowski/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## 1. Loading dataset

# %%
COVID_PREPROCESSED_DATA_PATH = "/Users/adamdabkowski/PycharmProjects/NLP-Project/data/preprocessed/covid"

# %%
data_json = pd.read_json(COVID_PREPROCESSED_DATA_PATH, orient="records", lines=True)

# %%
# dataset_1 = data_json.loc[data_json['label'] == 1].head(20)
# dataset_0 = data_json.loc[data_json['label'] == 0].head(20)

dataset_1 = data_json.loc[data_json['label'] == 1].head(476)
dataset_0 = data_json.loc[data_json['label'] == 0].head(476)

dataset = pd.concat([dataset_1, dataset_0])
dataset = dataset.sample(frac=1, random_state=10)

# %%
train_data, test_data = train_test_split(dataset, train_size=0.8, random_state=42)

# %% [markdown]
# ## 2. Data Analyzing

# %% [markdown]
# #### 2.1 Label distribution

# %%
DataAnalyzer.plot_label_distribution(dataset=dataset)

# %% [markdown]
# #### 2.2 Polarity

# %%
DataAnalyzer.plot_polarity_distribution(dataset=dataset)

# %% [markdown]
# #### 2.3 Subjectivity

# %%
DataAnalyzer.plot_subjectivity_distribution(dataset=dataset)

# %% [markdown]
# #### 2.4 Most Popular Words Map

# %%
most_popular_words = DataAnalyzer.get_most_popular_words(
    dataset=dataset,
    language="english",
    most_popular_words_num=100,
    label_type=None
)

# %%
most_popular_words_0 = DataAnalyzer.get_most_popular_words(
    dataset=dataset,
    language="english",
    most_popular_words_num=100,
    label_type=0
)

# %%
most_popular_words_1 = DataAnalyzer.get_most_popular_words(
    dataset=dataset,
    language="english",
    most_popular_words_num=100,
    label_type=1
)

# %%
DataAnalyzer.plot_most_popular_words_map(
    most_popular_words=most_popular_words,
    most_popular_words_num=50,
    label_type=None
)

# %%
DataAnalyzer.plot_most_popular_words_map(
    most_popular_words=most_popular_words_0,
    most_popular_words_num=50,
    label_type=0
)

# %%
DataAnalyzer.plot_most_popular_words_map(
    most_popular_words=most_popular_words_1,
    most_popular_words_num=50,
    label_type=1
)

# %% [markdown]
# #### 2.5 Most Popular Words Histogram

# %%
DataAnalyzer.plot_most_popular_words_histogram(
    most_popular_words=most_popular_words,
    most_popular_words_num=25,
    label_type=None
)

# %%
DataAnalyzer.plot_most_popular_words_histogram(
    most_popular_words=most_popular_words_0,
    most_popular_words_num=25,
    label_type=0
)

# %%
DataAnalyzer.plot_most_popular_words_histogram(
    most_popular_words=most_popular_words_1,
    most_popular_words_num=25,
    label_type=1
)
